# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
import mlflow

# %config IPCompleter.greedy=True

# %%
shops = pd.read_csv("../data/raw/shops.csv")

# %%
shops.head()
# Out:
#     Наименование                      Описание  \
# 0    Центральный                  торговый дом
# 1       Магеллан  многофункциональный комплекс
# 2   Плехановский                торговый центр
# 3  Тюменский ЦУМ                торговый центр
# 4      Континент                торговый центр
#
#                                              Рубрики                   Адрес  \
# 0           Торговые центры / Универсальные магазины           Некрасова, 10
# 1  Бизнес-центры; Торговые центры / Универсальные...      50 лет Октября, 14
# 2           Торговые центры / Универсальные магазины   Московский тракт, 142
# 3           Торговые центры / Универсальные магазины       Орджоникидзе, 63а
# 4           Торговые центры / Универсальные магазины  Червишевский тракт, 23
#
#   Комментарий к адресу  Почтовый индекс Микрорайон              Район   Город  \
# 0                  NaN         625000.0        NaN  Центральный округ  Тюмень
# ...

# %%
columns = shops.columns

# %%
for i in columns:
    print(list(shops[i].unique()))
# Out:
# ['Центральный', 'Магеллан', 'Плехановский', 'Тюменский ЦУМ', 'Континент', 'Блошинка', 'Калинка', 'Тюменский', 'Ямской', 'Яркий Сибиряк', 'Дарина', 'Зеленый Берег', 'Океан', 'П.О.Р.Т.', 'Рентал', 'Пассаж', 'Мальвинка', 'Москва', 'Арбат', 'Матрикс', 'Овентал Тауэр', 'Перестрой-ка!', 'Широтный', 'Галацентр', 'Для вас', 'Изобилие', 'Весна', 'Пышма', 'Амбар', 'Пригородный', 'Турана', 'Заречный двор', 'Левша', 'Новый Восточный', 'Магик', 'Тетрис', 'Модена', 'Биография', 'Ватутинский', 'Мистраль', 'Большая Ярмарка', 'Мебель-ковры', 'Радуга', 'Ямальский', 'Жемчужина', 'Инженер', 'Орхидея', 'Европейский', 'Тура', 'Среда. Звёздный', 'Яблоко', 'Фламинго', 'Джаз', 'Березняковский', 'Золотой ключик', 'Универсам', 'Циклон', 'Жарден', 'Казаровский', 'Парус', 'Престиж', 'На Герцена', 'Монблан', 'Виталий', 'Галерея', 'Юна', 'У озера', 'Осень', 'Верхний бор', 'Малина', 'Мамина Радость', 'РЕСПУБЛИКА', 'Восточный', 'Зелёные холмы', 'Браво', 'На Спасской', 'Загородный', 'Заречный', 'Шарм', 'Наташа', 'Кас
# ...

# %%
columns
# Out:
# Index(['Наименование', 'Описание', 'Рубрики', 'Адрес', 'Комментарий к адресу',
#        'Почтовый индекс', 'Микрорайон', 'Район', 'Город', 'Округ', 'Регион',
#        'Страна', 'Часы работы', 'Часовой пояс', 'Рейтинг',
#        'Количество отзывов', 'Телефон 1', 'Телефон 2', 'Телефон 3', 'E-mail',
#        'Веб-сайт', 'Twitter', 'ВКонтакте', 'WhatsApp 1', 'WhatsApp 2',
#        'Viber 1', 'Viber 2', 'Telegram', 'YouTube', 'Широта', 'Долгота',
#        '2GIS URL'],
#       dtype='object')

# %%
shops['Адрес'].unique()
# Out:
# array(['Некрасова, 10', '50 лет Октября, 14', 'Московский тракт, 142',
#        'Орджоникидзе, 63а', 'Червишевский тракт, 23',
#        'Московский тракт, 120 ст2', 'Республики, 65',
#        'Мельникайте, 126/3', 'Ямская, 118', 'Александра Логунова, 5а',
#        'Дмитрия Менделеева, 18', 'Алебашевская, 19', 'Республики, 39',
#        'Мельникайте, 126 к2', 'Герцена, 103', 'Советская, 54',
#        'Бакинских Комиссаров, 7', 'Первомайская, 7',
#        'Николая Чаплина, 115а', 'Пермякова, 7Б', 'Осипенко, 79',
#        'Пермякова, 1а', 'Широтная, 80', 'Герцена, 97',
#        'Червишевский тракт, 64а', 'Муравленко, 21', 'Газовиков, 4',
#        'Червишевский тракт, 66', 'Полевая, 18', 'Энергетиков, 66',
#        'Ямская, 77/1', '30 лет Победы, 91а', 'Солнечный проезд, 11',
#        'Барабинская, 50', 'Таллинская, 4а', 'Николая Фёдорова, 11 ст1',
#        'Валерии Гнаровской, 7', 'Холодильная, 134 к1', 'Трактовая, 137',
#        'Юганский проезд, 4 к1', '50 лет Октября, 29',
# ...

# %%
shops['Микрорайон'].unique()
# Out:
# array([nan, 'Четвертый\xa0м-н', 'Тюменский 3-й\xa0м-н', 'Район КПД',
#        '1-й заречный\xa0м-н', '2-й заречный\xa0м-н', 'Войновка',
#        'Пятый\xa0м-н', 'Шестой\xa0м-н', 'Ватутина\xa0м-н',
#        'Тюменский 2-й\xa0м-н', '3-й заречный\xa0м-н',
#        'Европейский\xa0м-н', 'Тура', 'Звёздный городок\xa0м-н',
#        'Тюменский 1-й\xa0м-н', 'МЖК', 'Югра\xa0м-н', 'Казарово',
#        'Южный\xa0м-н', 'Восточный 2\xa0м-н', 'Березняковский\xa0м-н',
#        'Мыс', 'Тарманы', 'Первый\xa0м-н', 'Комарово',
#        'Нефтяников\xa0пос.', 'СО Русское поле', 'Третий\xa0м-н',
#        'Суходолье\xa0м-н', 'Стрела\xa0м-н', 'Заречный\xa0м-н',
#        'Южный 2\xa0м-н', 'Маяк\xa0м-н', 'Тюменская слобода\xa0м-н',
#        'Парфёново\xa0м-н', 'Восточный\xa0м-н', 'Второй\xa0м-н',
#        'Видный\xa0м-н', 'Мелиораторов', 'Антипино\xa0м-н', 'СО Топаз',
#        'СО Приволье', 'Ямальский\xa0м-н', 'У озера\xa0квартал',
#        'Источник\xa0пос.', 'Дорожный', 'СНТСН Суходольное',
# ...

# %%
 shops['Район'].unique()
# Out:
# array(['Центральный округ', 'Калининский округ', 'Восточный округ',
#        'Ленинский округ', nan], dtype=object)

# %%
 shops['Город'].unique()
# Out:
# array(['Тюмень', nan, 'Ялуторовск', 'Заводоуковск'], dtype=object)

# %%
 shops['Округ'].unique()
# Out:
# array(['Тюмень городской округ', 'Тюменский район',
#        'Ялуторовск городской округ', 'Нижнетавдинский район',
#        'Тугулымский городской округ', 'Исетский район',
#        'Ялуторовский район', 'Заводоуковский городской округ',
#        'Ярковский район', 'Слободо-Туринский район'], dtype=object)

# %%
 shops['Регион'].unique()
# Out:
# array(['Тюменская область', 'Свердловская область'], dtype=object)
